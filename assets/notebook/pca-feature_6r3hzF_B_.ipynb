# %% [markdown]
# ### Preparing the Dataset

# %% [markdown]
# #### Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Importing the dataset

# %%
dataset = pd.read_csv('/project_data/data_asset/Wine.csv')
X = dataset.iloc[:, 0:13].values  #Explanatory variables
y = dataset.iloc[:, 13].values  #Target variable

# %%
dataset.head(2)
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1

# %%
X[0:2]
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, 1.560e+01, 1.270e+02, 2.800e+00,
#         3.060e+00, 2.800e-01, 2.290e+00, 5.640e+00, 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, 1.120e+01, 1.000e+02, 2.650e+00,
#         2.760e+00, 2.600e-01, 1.280e+00, 4.380e+00, 1.050e+00, 3.400e+00,
#         1.050e+03]])

# %%
y[0:2]
# Out:
# array([1, 1])

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X[0:2]
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#          0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#          0.36217728,  1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, -2.49084714,  0.01814502,
#          0.56864766,  0.73362894, -0.82071924, -0.54472099, -0.29332133,
#          0.40605066,  1.1134493 ,  0.96524152]])

# %% [markdown]
# #### Applying PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
X = pca.fit_transform(X)

# %%
X[0:2]
# Out:
# array([[ 3.31675081, -1.44346263],
#        [ 2.20946492,  0.33339289]])

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance*100
# Out:
# array([36.1988481 , 19.20749026])

# %% [markdown]
# ### Exporting the results

# %%
features = pd.DataFrame(X)
features.to_csv('/project_data/data_asset/features.csv')
features.head(2)
# Out:
#           0         1
# 0  3.316751 -1.443463
# 1  2.209465  0.333393

# %%
target = pd.DataFrame(y)
target.to_csv('/project_data/data_asset/target.csv')
target[0:2]
# Out:
#    0
# 0  1
# 1  1

# %%
# !pwd
# Out:
# /home/wsuser/work

# %%
# !ls /project_data/data_asset/
# Out:
# Wine.csv	      feature_engineering.py  model_scoring.py
# extract_and_score.py  features.csv	      target.csv
